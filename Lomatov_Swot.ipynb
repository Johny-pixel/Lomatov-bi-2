# %% [markdown]
# <a href="https://colab.research.google.com/github/Johny-pixel/Lomatov-bi-2/blob/main/Lomatov_Swot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Группа: 20БИ2; ФИО: Ломатов Антон Андреевич')
# !ln -fs /usr/share/zoneinfo/Europe/Moscow/etc/localtime
print("Дата выполнения задания:")
# !date

from google.colab import drive
drive.mount('/content/drive')
import os
print(os.getcwd())
print(os.listdir('./'))
print(os.listdir('/content/drive'))
print(os.listdir('/content/drive/MyDrive/Colab Notebooks'))
print ("Бизнес-идея: Открытие музыкального магазина")
# Out:
# Группа: 20БИ2; ФИО: Ломатов Антон Андреевич
# Дата выполнения задания:
# Wed Mar  3 20:49:52 MSK 2021
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content
# ['.config', 'drive', 'localtime', 'adc.json', 'sample_data']
# ['.shortcut-targets-by-id', 'MyDrive', '.file-revisions-by-id', '.Trash']
# ['Untitled0.ipynb', 'test1.txt', 'lesson1.txt', 'Ломатов 02.12.ipynb', 'Списки.ipynb', 'Lomatov']
# Бизнес-идея: Открытие музыкального магазина

# %%
from google.colab import auth
auth.authenticate_user()
import gspread
from oauth2client.client import GoogleCredentials
gc = gspread.authorize(GoogleCredentials.get_application_default())
table = gc.open_by_key('17o6rP4suHVk4x9JEQjEfe__ass3btHjfwrzwJ2kj9Wc')
worksheet = table.worksheet("Лист1")

rows = worksheet.get_all_values()
strenghts = list()
actions = list()
importance = list()
probability = list()
power = list()

i=0
for row in rows:
  if(i>0):
    print (i, row)
    strenghts.append(row[1])
    actions.append(row[2])
    importance.append(int(row[3]))
    probability.append(float(row[4]))
  
  i+=1
print('\n',strenghts, actions, importance, probability, sep='\n', end='\n\n')

import matplotlib.pyplot as plt
fig=plt.figure(figsize=(16,12), dpi=75)
plt.title('Сильные стороны',fontsize=40)
plt.xlabel('Свойства',fontsize=25)
plt.ylabel('Важность свойства',fontsize=25)
plt.bar (strenghts, probability, width=0.6)
plt.xticks(strenghts, fontsize=14)

plt.grid(True, color='r', linestyle='-', linewidth=0.8)
plt.show
# Out:
# 1 ['', 'Высокий уровень сервиса', 'Грамотное, качественное обучение персонала', '8', '0.8', '6.4', 'Отсутствие веб-сайта', 'Найм профессионала в области создания сайтов', '9', '0.8', '7.2', 'Расширение географии продаж', 'Открытие магазинов в других городах', '9', '0.7', '6.3', 'Узкая аудитория', 'Проведение качественных рекламных компаний, направленных на целевую аудиторию', '9', '0.8', '7.2']
# 2 ['', 'Интерактивные магазины', 'Интеграция интерактивных зон в магазины', '9', '0.6', '5.4', 'Отсутствие опыта продаж', 'Изучение научной литературы по теме', '4', '0.9', '3.6', 'Выход в сегмент премиальных товаров', 'Сотрудничество с премиальными брендами', '6', '0.6', '3.6', 'Высокая конкурентность', 'Составление грамотной торговой стратегии', '7', '0.8', '5.6']
# 3 ['', 'Профессиональные сотрудники', 'Тщательный отбор сотрудников', '10', '0.8', '8', '  Нет специалиста по конт.рекламе', 'Найм профессионала в области контекстной рекламы', '7', '0.8', '5.6', 'Проведение камерных концертов', 'Закупка оборудования для проведения концертов', '7', '0.6', '4.2', 'Большие затраты', 'Изначальная закупка менее дорогих музыкальных инструментов для новичков', '7', '0.9', '6.3']
# 4 ['', 'Качественные товары', 'Сотрудничество с надежными поставщиками', '10', '0.9', '9', 'Плохое знание рынка', 'Изучение рынка с помощью различных ресурсов', '5', '0.9', '4.5', 'Проведение в магазинах выставок ', 'Закупка экспонатов и оборудования для проведения выставок', '7', '0.6', '4.2', 'Снижение доходов части клиентов', 'Проведение акций для студентов, пенсионеров. Возможное снижение цен на товары низшей ценовой категории', '8', '0.4', '3.2']
#
#
# ['Высокий уровень сервиса', 'Интерактивные магазины', 'Профессиональные сотрудники', 'Качественные товары']
# ['Грамотное, качественное обучение персонала', 'Интеграция интерактивных зон в магазины', 'Тщательный отбор сотрудников', 'Сотрудничество с надежными поставщиками']
# [8, 9, 10, 10]
# [0.8, 0.6, 0.8, 0.9]
# <function matplotlib.pyplot.show>

# %%
rows = worksheet.get_all_values()
weaknesses = list()
actions = list()
importance = list()
probability = list()
power = list()

i=0
for row in rows:
  if(i>0):
    print (i, row)
    weaknesses.append(row[6])
    actions.append(row[7])
    importance.append(int(row[8]))
    probability.append(float(row[9]))
  
  i+=1
print('\n',weaknesses, actions, importance, probability, sep='\n', end='\n\n')

import matplotlib.pyplot as plt
fig=plt.figure(figsize=(16,12), dpi=75)
plt.title('Слабые стороны',fontsize=40)
plt.xlabel('Свойства',fontsize=25)
plt.ylabel('Важность свойства',fontsize=25)
plt.bar (weaknesses, probability, width=0.6)
plt.xticks(weaknesses, fontsize=14)

plt.grid(True, color='r', linestyle='-', linewidth=0.8)
plt.show
# Out:
# 1 ['', 'Высокий уровень сервиса', 'Грамотное, качественное обучение персонала', '8', '0.8', '6.4', 'Отсутствие веб-сайта', 'Найм профессионала в области создания сайтов', '9', '0.8', '7.2', 'Расширение географии продаж', 'Открытие магазинов в других городах', '9', '0.7', '6.3', 'Узкая аудитория', 'Проведение качественных рекламных компаний, направленных на целевую аудиторию', '9', '0.8', '7.2']
# 2 ['', 'Интерактивные магазины', 'Интеграция интерактивных зон в магазины', '9', '0.6', '5.4', 'Отсутствие опыта продаж', 'Изучение научной литературы по теме', '4', '0.9', '3.6', 'Выход в сегмент премиальных товаров', 'Сотрудничество с премиальными брендами', '6', '0.6', '3.6', 'Высокая конкурентность', 'Составление грамотной торговой стратегии', '7', '0.8', '5.6']
# 3 ['', 'Профессиональные сотрудники', 'Тщательный отбор сотрудников', '10', '0.8', '8', '  Нет специалиста по конт.рекламе', 'Найм профессионала в области контекстной рекламы', '7', '0.8', '5.6', 'Проведение камерных концертов', 'Закупка оборудования для проведения концертов', '7', '0.6', '4.2', 'Большие затраты', 'Изначальная закупка менее дорогих музыкальных инструментов для новичков', '7', '0.9', '6.3']
# 4 ['', 'Качественные товары', 'Сотрудничество с надежными поставщиками', '10', '0.9', '9', 'Плохое знание рынка', 'Изучение рынка с помощью различных ресурсов', '5', '0.9', '4.5', 'Проведение в магазинах выставок ', 'Закупка экспонатов и оборудования для проведения выставок', '7', '0.6', '4.2', 'Снижение доходов части клиентов', 'Проведение акций для студентов, пенсионеров. Возможное снижение цен на товары низшей ценовой категории', '8', '0.4', '3.2']
#
#
# ['Отсутствие веб-сайта', 'Отсутствие опыта продаж', '  Нет специалиста по конт.рекламе', 'Плохое знание рынка']
# ['Найм профессионала в области создания сайтов', 'Изучение научной литературы по теме', 'Найм профессионала в области контекстной рекламы', 'Изучение рынка с помощью различных ресурсов']
# [9, 4, 7, 5]
# [0.8, 0.9, 0.8, 0.9]
# <function matplotlib.pyplot.show>

# %%
rows = worksheet.get_all_values()
opportunities = list()
actions = list()
importance = list()
probability = list()
power = list()

i=0
for row in rows:
  if(i>0):
    print (i, row)
    opportunities.append(row[11])
    actions.append(row[12])
    importance.append(int(row[13]))
    probability.append(float(row[14]))
  
  i+=1
print('\n',opportunities, actions, importance, probability, sep='\n', end='\n\n')


import matplotlib.pyplot as plt
fig=plt.figure(figsize=(16,12), dpi=75)
plt.title('Возможности',fontsize=40)
plt.xlabel('Свойства',fontsize=25)
plt.ylabel('Важность свойства',fontsize=25)
plt.bar (opportunities, probability, width=0.6)
plt.xticks(opportunities, fontsize=11)

plt.grid(True, color='r', linestyle='-', linewidth=0.8)
plt.show
# Out:
# 1 ['', 'Высокий уровень сервиса', 'Грамотное, качественное обучение персонала', '8', '0.8', '6.4', 'Отсутствие веб-сайта', 'Найм профессионала в области создания сайтов', '9', '0.8', '7.2', 'Расширение географии продаж', 'Открытие магазинов в других городах', '9', '0.7', '6.3', 'Узкая аудитория', 'Проведение качественных рекламных компаний, направленных на целевую аудиторию', '9', '0.8', '7.2']
# 2 ['', 'Интерактивные магазины', 'Интеграция интерактивных зон в магазины', '9', '0.6', '5.4', 'Отсутствие опыта продаж', 'Изучение научной литературы по теме', '4', '0.9', '3.6', 'Выход в сегмент премиальных товаров', 'Сотрудничество с премиальными брендами', '6', '0.6', '3.6', 'Высокая конкурентность', 'Составление грамотной торговой стратегии', '7', '0.8', '5.6']
# 3 ['', 'Профессиональные сотрудники', 'Тщательный отбор сотрудников', '10', '0.8', '8', '  Нет специалиста по конт.рекламе', 'Найм профессионала в области контекстной рекламы', '7', '0.8', '5.6', 'Проведение камерных концертов', 'Закупка оборудования для проведения концертов', '7', '0.6', '4.2', 'Большие затраты', 'Изначальная закупка менее дорогих музыкальных инструментов для новичков', '7', '0.9', '6.3']
# 4 ['', 'Качественные товары', 'Сотрудничество с надежными поставщиками', '10', '0.9', '9', 'Плохое знание рынка', 'Изучение рынка с помощью различных ресурсов', '5', '0.9', '4.5', 'Проведение в магазинах выставок ', 'Закупка экспонатов и оборудования для проведения выставок', '7', '0.6', '4.2', 'Снижение доходов части клиентов', 'Проведение акций для студентов, пенсионеров. Возможное снижение цен на товары низшей ценовой категории', '8', '0.4', '3.2']
#
#
# ['Расширение географии продаж', 'Выход в сегмент премиальных товаров', 'Проведение камерных концертов', 'Проведение в магазинах выставок ']
# ['Открытие магазинов в других городах', 'Сотрудничество с премиальными брендами', 'Закупка оборудования для проведения концертов', 'Закупка экспонатов и оборудования для проведения выставок']
# [9, 6, 7, 7]
# [0.7, 0.6, 0.6, 0.6]
# <function matplotlib.pyplot.show>

# %%
rows = worksheet.get_all_values()
threats = list()
actions = list()
importance = list()
probability = list()
power = list()

i=0
for row in rows:
  if(i>0):
    print (i, row)
    threats.append(row[16])
    actions.append(row[17])
    importance.append(int(row[18]))
    probability.append(float(row[19]))
  
  i+=1
print('\n',threats, actions, importance, probability, sep='\n', end='\n\n')

import matplotlib.pyplot as plt
fig=plt.figure(figsize=(16,12), dpi=75)
plt.title('Угрозы',fontsize=40)
plt.xlabel('Свойства',fontsize=25)
plt.ylabel('Важность свойства',fontsize=25)
plt.bar (threats, probability, width=0.6)
plt.xticks(threats, fontsize=11)

plt.grid(True, color='r', linestyle='-', linewidth=0.8)
plt.show
# Out:
# 1 ['', 'Высокий уровень сервиса', 'Грамотное, качественное обучение персонала', '8', '0.8', '6.4', 'Отсутствие веб-сайта', 'Найм профессионала в области создания сайтов', '9', '0.8', '7.2', 'Расширение географии продаж', 'Открытие магазинов в других городах', '9', '0.7', '6.3', 'Узкая аудитория', 'Проведение качественных рекламных компаний, направленных на целевую аудиторию', '9', '0.8', '7.2']
# 2 ['', 'Интерактивные магазины', 'Интеграция интерактивных зон в магазины', '9', '0.6', '5.4', 'Отсутствие опыта продаж', 'Изучение научной литературы по теме', '4', '0.9', '3.6', 'Выход в сегмент премиальных товаров', 'Сотрудничество с премиальными брендами', '6', '0.6', '3.6', 'Высокая конкурентность', 'Составление грамотной торговой стратегии', '7', '0.8', '5.6']
# 3 ['', 'Профессиональные сотрудники', 'Тщательный отбор сотрудников', '10', '0.8', '8', '  Нет специалиста по конт.рекламе', 'Найм профессионала в области контекстной рекламы', '7', '0.8', '5.6', 'Проведение камерных концертов', 'Закупка оборудования для проведения концертов', '7', '0.6', '4.2', 'Большие затраты', 'Изначальная закупка менее дорогих музыкальных инструментов для новичков', '7', '0.9', '6.3']
# 4 ['', 'Качественные товары', 'Сотрудничество с надежными поставщиками', '10', '0.9', '9', 'Плохое знание рынка', 'Изучение рынка с помощью различных ресурсов', '5', '0.9', '4.5', 'Проведение в магазинах выставок ', 'Закупка экспонатов и оборудования для проведения выставок', '7', '0.6', '4.2', 'Снижение доходов части клиентов', 'Проведение акций для студентов, пенсионеров. Возможное снижение цен на товары низшей ценовой категории', '8', '0.4', '3.2']
#
#
# ['Узкая аудитория', 'Высокая конкурентность', 'Большие затраты', 'Снижение доходов части клиентов']
# ['Проведение качественных рекламных компаний, направленных на целевую аудиторию', 'Составление грамотной торговой стратегии', 'Изначальная закупка менее дорогих музыкальных инструментов для новичков', 'Проведение акций для студентов, пенсионеров. Возможное снижение цен на товары низшей ценовой категории']
# [9, 7, 7, 8]
# [0.8, 0.8, 0.9, 0.4]
# <function matplotlib.pyplot.show>

# %%
rows = worksheet.get_all_values()
Power_strenghts = list()
Power_weak = list()
Power_opport = list()
Power_threats = list()

i=0
for row in rows:
  if(i>0):
    print (i, row)
    Power_strenghts.append(float(row[5]))
    Power_weak.append(float(row[10]))
    Power_opport.append(float(row[15]))
    Power_threats.append(float(row[20]))
  
  i+=1

print('\n',Power_strenghts, Power_weak, Power_opport, Power_threats, sep='\n', end='\n\n')
sum_strenghts = sum(Power_strenghts)
sum_weak = -sum(Power_weak)
sum_opport = sum(Power_opport)
sum_threats = -sum(Power_threats)

print(sum_strenghts,sum_weak,sum_opport,sum_threats)
sum_power=(sum_strenghts+sum_weak+sum_opport+sum_threats)
print(sum_power)

list_sum=[sum_strenghts,sum_weak,sum_opport,sum_threats,sum_power]
list_names=["Strenghts","Weaknesses","Opportunities","Treats","Overall"]

import matplotlib.pyplot as plt
fig=plt.figure(figsize=(16,12), dpi=75)
plt.title('SWOT-анализ',fontsize=40)
plt.xlabel('Свойства',fontsize=25)
plt.ylabel('Важность свойства',fontsize=25)
plt.bar (list_names, list_sum, width=0.6)
plt.xticks(list_names, fontsize=15)

plt.grid(True, color='r', linestyle='-', linewidth=0.8)
plt.draw
plt.show

print("Strenghts= ", sum_strenghts)
print("Weaknesses= ", sum_weak)
print("Opportunities= ", sum_opport)
print("Threats= ", sum_threats)
print("Overall= ", sum_power)
# Out:
# 1 ['', 'Высокий уровень сервиса', 'Грамотное, качественное обучение персонала', '8', '0.8', '6.4', 'Отсутствие веб-сайта', 'Найм профессионала в области создания сайтов', '9', '0.8', '7.2', 'Расширение географии продаж', 'Открытие магазинов в других городах', '9', '0.7', '6.3', 'Узкая аудитория', 'Проведение качественных рекламных компаний, направленных на целевую аудиторию', '9', '0.8', '7.2']
# 2 ['', 'Интерактивные магазины', 'Интеграция интерактивных зон в магазины', '9', '0.6', '5.4', 'Отсутствие опыта продаж', 'Изучение научной литературы по теме', '4', '0.9', '3.6', 'Выход в сегмент премиальных товаров', 'Сотрудничество с премиальными брендами', '6', '0.6', '3.6', 'Высокая конкурентность', 'Составление грамотной торговой стратегии', '7', '0.8', '5.6']
# 3 ['', 'Профессиональные сотрудники', 'Тщательный отбор сотрудников', '10', '0.8', '8', '  Нет специалиста по конт.рекламе', 'Найм профессионала в области контекстной рекламы', '7', '0.8', '5.6', 'Проведение камерных концертов', 'Закупка оборудования для проведения концертов', '7', '0.6', '4.2', 'Большие затраты', 'Изначальная закупка менее дорогих музыкальных инструментов для новичков', '7', '0.9', '6.3']
# 4 ['', 'Качественные товары', 'Сотрудничество с надежными поставщиками', '10', '0.9', '9', 'Плохое знание рынка', 'Изучение рынка с помощью различных ресурсов', '5', '0.9', '4.5', 'Проведение в магазинах выставок ', 'Закупка экспонатов и оборудования для проведения выставок', '7', '0.6', '4.2', 'Снижение доходов части клиентов', 'Проведение акций для студентов, пенсионеров. Возможное снижение цен на товары низшей ценовой категории', '8', '0.4', '3.2']
#
#
# [6.4, 5.4, 8.0, 9.0]
# [7.2, 3.6, 5.6, 4.5]
# [6.3, 3.6, 4.2, 4.2]
# [7.2, 5.6, 6.3, 3.2]
#
# 28.8 -20.9 18.3 -22.3
# 3.900000000000002
# Strenghts=  28.8
# Weaknesses=  -20.9
# Opportunities=  18.3
# Threats=  -22.3
# Overall=  3.900000000000002
